# %%
import scanpy as sc
from scib_metrics.benchmark import Benchmarker

# %%
adata = sc.read_h5ad("/Users/hauke/Desktop/T2D_Myeloid/data/CellTypist_Myeloid.h5ad")

# %%
adata.shape
# Out:
# (8509, 43086)

# %%
adata.var
# Out:
#              vf_vst_counts.CV7320_mean  vf_vst_counts.CV7320_variance  \
# MIR1302-2HG                        0.0                            0.0
# FAM138A                            0.0                            0.0
# OR4F5                              0.0                            0.0
# AL627309.1                         0.0                            0.0
# AL627309.3                         0.0                            0.0
# ...                                ...                            ...
# AC011840.1                         0.0                            0.0
# AC020911.3                         0.0                            0.0
# U62631.1                           0.0                            0.0
# AP000553.9                         0.0                            0.0
# AC234775.4                         0.0                            0.0
#
#              vf_vst_counts.CV7320_variance.expected  \
# MIR1302-2HG                                     0.0
# FAM138A                                         0.0
# OR4F5                                           0.0
# AL627309.1                                      0.0
# AL627309.3                                      0.0
# ...                                             ...
# AC011840.1                                      0.0
# AC020911.3                                      0.0
# U62631.1                                        0.0
# AP000553.9                                      0.0
# AC234775.4                                      0.0
#
#              vf_vst_counts.CV7320_variance.standardized  \
# MIR1302-2HG                                         0.0
# FAM138A                                             0.0
# OR4F5                                               0.0
# AL627309.1                                          0.0
# AL627309.3                                          0.0
# ...                                                 ...
# AC011840.1                                          0.0
# AC020911.3                                          0.0
# U62631.1                                            0.0
# AP000553.9                                          0.0
# AC234775.4                                          0.0
#
#              vf_vst_counts.CV7320_variable  vf_vst_counts.CV7320_rank  \
# MIR1302-2HG                          False                -2147483648
# FAM138A                              False                -2147483648
# OR4F5                                False                -2147483648
# AL627309.1                           False                -2147483648
# AL627309.3                           False                -2147483648
# ...                                    ...                        ...
# AC011840.1                           False                -2147483648
# AC020911.3                           False                -2147483648
# U62631.1                             False                -2147483648
# AP000553.9                           False                -2147483648
# AC234775.4                           False                -2147483648
#
#              vf_vst_counts.one_mean  vf_vst_counts.one_variance  \
# MIR1302-2HG                     0.0                         0.0
# FAM138A                         0.0                         0.0
# OR4F5                           0.0                         0.0
# AL627309.1                      0.0                         0.0
# AL627309.3                      0.0                         0.0
# ...                             ...                         ...
# AC011840.1                      0.0                         0.0
# AC020911.3                      0.0                         0.0
# U62631.1                        0.0                         0.0
# AP000553.9                      0.0                         0.0
# AC234775.4                      0.0                         0.0
#
#              vf_vst_counts.one_variance.expected  \
# MIR1302-2HG                                  0.0
# FAM138A                                      0.0
# OR4F5                                        0.0
# AL627309.1                                   0.0
# AL627309.3                                   0.0
# ...                                          ...
# AC011840.1                                   0.0
# AC020911.3                                   0.0
# U62631.1                                     0.0
# AP000553.9                                   0.0
# AC234775.4                                   0.0
#
#              vf_vst_counts.one_variance.standardized  ...  \
# MIR1302-2HG                                      0.0  ...
# FAM138A                                          0.0  ...
# OR4F5                                            0.0  ...
# AL627309.1                                       0.0  ...
# AL627309.3                                       0.0  ...
# ...                                              ...  ...
# AC011840.1                                       0.0  ...
# AC020911.3                                       0.0  ...
# U62631.1                                         0.0  ...
# AP000553.9                                       0.0  ...
# AC234775.4                                       0.0  ...
#
#              vf_vst_counts.seven_variable  vf_vst_counts.seven_rank  \
# MIR1302-2HG                         False               -2147483648
# FAM138A                             False               -2147483648
# OR4F5                               False               -2147483648
# AL627309.1                          False               -2147483648
# AL627309.3                          False               -2147483648
# ...                                   ...                       ...
# AC011840.1                          False               -2147483648
# AC020911.3                          False               -2147483648
# U62631.1                            False               -2147483648
# AP000553.9                          False               -2147483648
# AC234775.4                          False               -2147483648
#
#              vf_vst_counts.eight_mean  vf_vst_counts.eight_variance  \
# MIR1302-2HG                  0.000000                      0.000000
# FAM138A                      0.000000                      0.000000
# OR4F5                        0.000000                      0.000000
# AL627309.1                   0.000000                      0.000000
# AL627309.3                   0.000000                      0.000000
# ...                               ...                           ...
# AC011840.1                   0.000000                      0.000000
# AC020911.3                   0.003717                      0.003717
# U62631.1                     0.000000                      0.000000
# AP000553.9                   0.000000                      0.000000
# AC234775.4                   0.000000                      0.000000
#
#              vf_vst_counts.eight_variance.expected  \
# MIR1302-2HG                               0.000000
# FAM138A                                   0.000000
# OR4F5                                     0.000000
# AL627309.1                                0.000000
# AL627309.3                                0.000000
# ...                                            ...
# AC011840.1                                0.000000
# AC020911.3                                0.003718
# U62631.1                                  0.000000
# AP000553.9                                0.000000
# AC234775.4                                0.000000
#
#              vf_vst_counts.eight_variance.standardized  \
# MIR1302-2HG                                    0.00000
# FAM138A                                        0.00000
# OR4F5                                          0.00000
# AL627309.1                                     0.00000
# AL627309.3                                     0.00000
# ...                                                ...
# AC011840.1                                     0.00000
# AC020911.3                                     0.99989
# U62631.1                                       0.00000
# AP000553.9                                     0.00000
# AC234775.4                                     0.00000
#
#              vf_vst_counts.eight_variable  vf_vst_counts.eight_rank  \
# MIR1302-2HG                         False               -2147483648
# FAM138A                             False               -2147483648
# OR4F5                               False               -2147483648
# AL627309.1                          False               -2147483648
# AL627309.3                          False               -2147483648
# ...                                   ...                       ...
# AC011840.1                          False               -2147483648
# AC020911.3                          False               -2147483648
# U62631.1                            False               -2147483648
# AP000553.9                          False               -2147483648
# AC234775.4                          False               -2147483648
#
#              var.features  var.features.rank
# MIR1302-2HG           NaN        -2147483648
# FAM138A               NaN        -2147483648
# OR4F5                 NaN        -2147483648
# AL627309.1            NaN        -2147483648
# AL627309.3            NaN        -2147483648
# ...                   ...                ...
# AC011840.1            NaN        -2147483648
# AC020911.3            NaN        -2147483648
# U62631.1              NaN        -2147483648
# AP000553.9            NaN        -2147483648
# AC234775.4            NaN        -2147483648
#
# [43086 rows x 176 columns]

# %%
adata.obs
# Out:
#                             nCount_RNA  nFeature_RNA conditions study   bmi  \
# G_AAAGATGGTCTGCAAT-1           14608.0          3278         ND     G  lean
# G_AACTCTTGTCGGGTCT-1             779.0           424         ND     G  lean
# G_AACTTTCGTCCTGCTT-1            4362.0          1325         ND     G  lean
# G_AAGCCGCCATGCCTTC-1            5877.0          1461         ND     G  lean
# G_AAGGTTCAGCACGCCT-1            6510.0          1478         ND     G  lean
# ...                                ...           ...        ...   ...   ...
# H_eight_TTGGCAACAGCCACCA.1     12248.0          3503         ND     H   NaN
# H_eight_TTGTAGGTCTCCAGGG.1     12608.0          3078         ND     H   NaN
# H_eight_TTTACTGAGGGTTTCT.1      8933.0          2806         ND     H   NaN
# H_eight_TTTCCTCAGCGTAGTG.1      3210.0          1508         ND     H   NaN
# H_eight_TTTGCGCTCTGGTGTA.1      5051.0          1861         ND     H   NaN
#
#                            Carotid_stenosis  Pat_ID  combined_ID  percent.mt  \
# G_AAAGATGGTCTGCAAT-1            Symptomatic  CV7225  G_CV7225_ND    4.100493
# G_AACTCTTGTCGGGTCT-1            Symptomatic  CV7225  G_CV7225_ND    0.000000
# G_AACTTTCGTCCTGCTT-1            Symptomatic  CV7225  G_CV7225_ND    3.943145
# G_AAGCCGCCATGCCTTC-1            Symptomatic  CV7225  G_CV7225_ND    2.654416
# G_AAGGTTCAGCACGCCT-1            Symptomatic  CV7225  G_CV7225_ND    2.273425
# ...                                     ...     ...          ...         ...
# H_eight_TTGGCAACAGCCACCA.1              NaN   eight   H_eight_ND    0.922600
# H_eight_TTGTAGGTCTCCAGGG.1              NaN   eight   H_eight_ND    2.054251
# H_eight_TTTACTGAGGGTTTCT.1              NaN   eight   H_eight_ND    3.156834
# H_eight_TTTCCTCAGCGTAGTG.1              NaN   eight   H_eight_ND    6.012461
# H_eight_TTTGCGCTCTGGTGTA.1              NaN   eight   H_eight_ND    1.979806
#
#                             percent.rps  ...  cca_clusters seurat_clusters  \
# G_AAAGATGGTCTGCAAT-1           9.412651  ...            11               9
# G_AACTCTTGTCGGGTCT-1           4.621309  ...             3               3
# G_AACTTTCGTCCTGCTT-1          13.801009  ...             1               9
# G_AAGCCGCCATGCCTTC-1           9.954058  ...             5              18
# G_AAGGTTCAGCACGCCT-1           7.680492  ...             9               6
# ...                                 ...  ...           ...             ...
# H_eight_TTGGCAACAGCCACCA.1    12.516329  ...            12               2
# H_eight_TTGTAGGTCTCCAGGG.1     9.835025  ...             5               4
# H_eight_TTTACTGAGGGTTTCT.1     6.627113  ...             1               5
# H_eight_TTTCCTCAGCGTAGTG.1     3.862928  ...             1              10
# H_eight_TTTGCGCTCTGGTGTA.1     9.641655  ...             1               1
#
#                            rpca_clusters harmony_clusters mnn_clusters  \
# G_AAAGATGGTCTGCAAT-1                  17                9            9
# G_AACTCTTGTCGGGTCT-1                   3                3            3
# G_AACTTTCGTCCTGCTT-1                  17                9            9
# G_AAGCCGCCATGCCTTC-1                  10               18           18
# G_AAGGTTCAGCACGCCT-1                   4                6            6
# ...                                  ...              ...          ...
# H_eight_TTGGCAACAGCCACCA.1             5                2            2
# H_eight_TTGTAGGTCTCCAGGG.1             2                4            4
# H_eight_TTTACTGAGGGTTTCT.1             1                5            5
# H_eight_TTTCCTCAGCGTAGTG.1            13               10           10
# H_eight_TTTGCGCTCTGGTGTA.1            14                1            1
#
#                            scvi_clusters          predicted_labels  \
# G_AAAGATGGTCTGCAAT-1                   9                       DC1
# G_AACTCTTGTCGGGTCT-1                   3      Alveolar macrophages
# G_AACTTTCGTCCTGCTT-1                   9       Classical monocytes
# G_AAGCCGCCATGCCTTC-1                  18             Migratory DCs
# G_AAGGTTCAGCACGCCT-1                   6               Macrophages
# ...                                  ...                       ...
# H_eight_TTGGCAACAGCCACCA.1             2                       pDC
# H_eight_TTGTAGGTCTCCAGGG.1             4                       DC2
# H_eight_TTTACTGAGGGTTTCT.1             5  Intermediate macrophages
# H_eight_TTTCCTCAGCGTAGTG.1            10       Classical monocytes
# H_eight_TTTGCGCTCTGGTGTA.1             1       Classical monocytes
#
#                            over_clustering           majority_voting  \
# G_AAAGATGGTCTGCAAT-1                    74               Macrophages
# G_AACTCTTGTCGGGTCT-1                    58               Macrophages
# G_AACTTTCGTCCTGCTT-1                    16       Classical monocytes
# G_AAGCCGCCATGCCTTC-1                    76             Migratory DCs
# G_AAGGTTCAGCACGCCT-1                    28  Intermediate macrophages
# ...                                    ...                       ...
# H_eight_TTGGCAACAGCCACCA.1              68                       pDC
# H_eight_TTGTAGGTCTCCAGGG.1              59                       DC2
# H_eight_TTTACTGAGGGTTTCT.1              62  Intermediate macrophages
# H_eight_TTTCCTCAGCGTAGTG.1              15       Classical monocytes
# H_eight_TTTGCGCTCTGGTGTA.1              83       Classical monocytes
#
#                            conf_score
# G_AAAGATGGTCTGCAAT-1         0.055636
# G_AACTCTTGTCGGGTCT-1         0.453090
# G_AACTTTCGTCCTGCTT-1         0.018434
# G_AAGCCGCCATGCCTTC-1         0.993403
# G_AAGGTTCAGCACGCCT-1         0.823976
# ...                               ...
# H_eight_TTGGCAACAGCCACCA.1   1.000000
# H_eight_TTGTAGGTCTCCAGGG.1   0.999993
# H_eight_TTTACTGAGGGTTTCT.1   0.116293
# H_eight_TTTCCTCAGCGTAGTG.1   0.983729
# H_eight_TTTGCGCTCTGGTGTA.1   0.997093
#
# [8509 rows x 21 columns]

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_harmony, X_integrated.cca, X_integrated.mnn, X_integrated.rpca, X_integrated.scvi, X_pca, X_umap.cca, X_umap.harmony, X_umap.mnn, X_umap.rpca, X_umap.scvi

# %%
bm = Benchmarker(
    adata,
    batch_key="conditions",
    label_key="majority_voting",
    embedding_obsm_keys=["X_harmony", "X_integrated.cca", "X_integrated.mnn", "X_integrated.rpca", "X_integrated.scvi"],
    n_jobs=-1,
)
bm.benchmark()
# Out:
# Computing neighbors: 100%|████████████████████████| 5/5 [00:23<00:00,  4.76s/it]
# Embeddings:   0%|                                         | 0/5 [00:00<?, ?it/s]
# Metrics:   0%|                                           | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|        | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%| | 1/10 [00:01<00:14,  1.64s/it, Bio conservation: isolated_labels
# Metrics:  10%| | 1/10 [00:01<00:14,  1.64s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:05<00:22,  2.81s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:05<00:22,  2.81s/it, Bio conservation: silhouette_labe
# Metrics:  30%|▎| 3/10 [00:05<00:11,  1.65s/it, Bio conservation: silhouette_labe
# Metrics:  30%|█▊    | 3/10 [00:05<00:11,  1.65s/it, Bio conservation: clisi_knn]
# Metrics:  40%|██▍   | 4/10 [00:06<00:08,  1.44s/it, Bio conservation: clisi_knn]
# Metrics:  40%|▍| 4/10 [00:06<00:08,  1.44s/it, Batch correction: silhouette_batc
# Metrics:  50%|▌| 5/10 [00:13<00:17,  3.56s/it, Batch correction: silhouette_batc
# Metrics:  50%|███   | 5/10 [00:13<00:17,  3.56s/it, Batch correction: ilisi_knn]
# Metrics:  60%|███▌  | 6/10 [00:14<00:09,  2.42s/it, Batch correction: ilisi_knn]
# Metrics:  60%|▌| 6/10 [00:14<00:09,  2.42s/it, Batch correction: kbet_per_label]/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|▋| 7/10 [00:27<00:18,  6.07s/it, Batch correction: kbet_per_label]
# Metrics:  70%|▋| 7/10 [00:27<00:18,  6.07s/it, Batch correction: graph_connectiv/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Metrics:  80%|▊| 8/10 [00:27<00:12,  6.07s/it, Batch correction: pcr_comparison]
# Embeddings:  20%|██████▌                          | 1/5 [00:28<01:55, 28.76s/it]
# Metrics:   0%|                                           | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|        | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%| | 1/10 [00:00<00:03,  2.89it/s, Bio conservation: isolated_labels
# Metrics:  10%| | 1/10 [00:00<00:03,  2.89it/s, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:19,  2.44s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:19,  2.44s/it, Bio conservation: silhouette_labe
# Metrics:  30%|▎| 3/10 [00:04<00:10,  1.47s/it, Bio conservation: silhouette_labe
# Metrics:  30%|█▊    | 3/10 [00:04<00:10,  1.47s/it, Bio conservation: clisi_knn]
# Metrics:  40%|██▍   | 4/10 [00:04<00:05,  1.07it/s, Bio conservation: clisi_knn]
# Metrics:  40%|▍| 4/10 [00:04<00:05,  1.07it/s, Batch correction: silhouette_batc
# Metrics:  50%|▌| 5/10 [00:04<00:03,  1.52it/s, Batch correction: silhouette_batc
# Metrics:  50%|███   | 5/10 [00:04<00:03,  1.52it/s, Batch correction: ilisi_knn]
# Metrics:  60%|███▌  | 6/10 [00:04<00:01,  2.09it/s, Batch correction: ilisi_knn]
# Metrics:  60%|▌| 6/10 [00:04<00:01,  2.09it/s, Batch correction: kbet_per_label]/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|▋| 7/10 [00:16<00:12,  4.02s/it, Batch correction: kbet_per_label]
# Metrics:  70%|▋| 7/10 [00:16<00:12,  4.02s/it, Batch correction: graph_connectiv/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Metrics:  80%|▊| 8/10 [00:16<00:08,  4.02s/it, Batch correction: pcr_comparison]
# Embeddings:  40%|█████████████▏                   | 2/5 [00:45<01:04, 21.49s/it]
# Metrics:   0%|                                           | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|        | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%| | 1/10 [00:04<00:40,  4.53s/it, Bio conservation: isolated_labels
# Metrics:  10%| | 1/10 [00:04<00:40,  4.53s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:09<00:38,  4.80s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:09<00:38,  4.80s/it, Bio conservation: silhouette_labe
# Metrics:  30%|▎| 3/10 [00:13<00:30,  4.31s/it, Bio conservation: silhouette_labe
# Metrics:  30%|█▊    | 3/10 [00:13<00:30,  4.31s/it, Bio conservation: clisi_knn]
# Metrics:  40%|██▍   | 4/10 [00:13<00:15,  2.66s/it, Bio conservation: clisi_knn]
# Metrics:  40%|▍| 4/10 [00:13<00:15,  2.66s/it, Batch correction: silhouette_batc
# Metrics:  50%|▌| 5/10 [00:15<00:11,  2.32s/it, Batch correction: silhouette_batc
# Metrics:  50%|███   | 5/10 [00:15<00:11,  2.32s/it, Batch correction: ilisi_knn]
# Metrics:  60%|▌| 6/10 [00:15<00:09,  2.32s/it, Batch correction: kbet_per_label]/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|▋| 7/10 [00:26<00:12,  4.01s/it, Batch correction: kbet_per_label]
# Metrics:  70%|▋| 7/10 [00:26<00:12,  4.01s/it, Batch correction: graph_connectiv/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Metrics:  80%|▊| 8/10 [00:26<00:08,  4.01s/it, Batch correction: pcr_comparison]
# Embeddings:  60%|███████████████████▊             | 3/5 [01:11<00:47, 23.79s/it]
# Metrics:   0%|                                           | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|        | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%| | 1/10 [00:00<00:03,  2.96it/s, Bio conservation: isolated_labels
# Metrics:  10%| | 1/10 [00:00<00:03,  2.96it/s, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:19,  2.44s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:19,  2.44s/it, Bio conservation: silhouette_labe
# Metrics:  30%|▎| 3/10 [00:04<00:10,  1.47s/it, Bio conservation: silhouette_labe
# Metrics:  30%|█▊    | 3/10 [00:04<00:10,  1.47s/it, Bio conservation: clisi_knn]
# Metrics:  40%|██▍   | 4/10 [00:04<00:05,  1.07it/s, Bio conservation: clisi_knn]
# Metrics:  40%|▍| 4/10 [00:04<00:05,  1.07it/s, Batch correction: silhouette_batc
# Metrics:  50%|▌| 5/10 [00:04<00:03,  1.55it/s, Batch correction: silhouette_batc
# Metrics:  50%|███   | 5/10 [00:04<00:03,  1.55it/s, Batch correction: ilisi_knn]
# Metrics:  60%|▌| 6/10 [00:04<00:02,  1.55it/s, Batch correction: kbet_per_label]/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|▋| 7/10 [00:14<00:08,  2.76s/it, Batch correction: kbet_per_label]
# Metrics:  70%|▋| 7/10 [00:14<00:08,  2.76s/it, Batch correction: graph_connectiv/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  80%|██████████████████████████▍      | 4/5 [01:26<00:20, 20.13s/it]
# Metrics:   0%|                                           | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|        | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%| | 1/10 [00:00<00:03,  2.82it/s, Bio conservation: isolated_labels
# Metrics:  10%| | 1/10 [00:00<00:03,  2.82it/s, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:20,  2.62s/it, Bio conservation: nmi_ari_cluster
# Metrics:  20%|▏| 2/10 [00:04<00:20,  2.62s/it, Bio conservation: silhouette_labe
# Metrics:  30%|▎| 3/10 [00:04<00:11,  1.59s/it, Bio conservation: silhouette_labe
# Metrics:  30%|█▊    | 3/10 [00:04<00:11,  1.59s/it, Bio conservation: clisi_knn]
# Metrics:  40%|▍| 4/10 [00:05<00:09,  1.59s/it, Batch correction: silhouette_batc
# Metrics:  50%|▌| 5/10 [00:05<00:03,  1.33it/s, Batch correction: silhouette_batc
# Metrics:  50%|███   | 5/10 [00:05<00:03,  1.33it/s, Batch correction: ilisi_knn]
# Metrics:  60%|▌| 6/10 [00:05<00:03,  1.33it/s, Batch correction: kbet_per_label]/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
#
# Metrics:  70%|▋| 7/10 [00:14<00:07,  2.41s/it, Batch correction: kbet_per_label]
# Metrics:  70%|▋| 7/10 [00:14<00:07,  2.41s/it, Batch correction: graph_connectiv/Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/_graph_connectivity.py:30: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Metrics:  80%|▊| 8/10 [00:14<00:04,  2.41s/it, Batch correction: pcr_comparison]
# Embeddings: 100%|█████████████████████████████████| 5/5 [01:40<00:00, 20.08s/it]

# %%
import matplotlib.pyplot as plt

# %%
bm.plot_results_table(min_max_scale=False)

# %%
bm.plot_results_table(min_max_scale=True)
# Out:
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py:268: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Aggregate score' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[_METRIC_TYPE, per_class_score.columns] = _AGGREGATE_SCORE
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py:268: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Aggregate score' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[_METRIC_TYPE, per_class_score.columns] = _AGGREGATE_SCORE
# /Users/hauke/anaconda3/lib/python3.11/site-packages/scib_metrics/benchmark/_core.py:268: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Aggregate score' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[_METRIC_TYPE, per_class_score.columns] = _AGGREGATE_SCORE
